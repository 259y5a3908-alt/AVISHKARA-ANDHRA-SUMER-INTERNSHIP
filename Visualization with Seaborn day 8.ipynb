# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("products-100.csv")

# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

print("Numeric Columns:")
print(numeric_df.columns)

# -------------------------------
# 1. Correlation Matrix
# -------------------------------
print("\nCorrelation Matrix:")
corr = numeric_df.corr()
print(corr)

# -------------------------------
# 2. Heatmap
# -------------------------------
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# -------------------------------
# 3. Kernel Density Estimate (KDE)
# -------------------------------
if len(numeric_df.columns) > 0:
    col = numeric_df.columns[0]

    plt.figure(figsize=(8, 5))
    sns.kdeplot(data=numeric_df, x=col, fill=True)
    plt.title(f"KDE Plot of {col}")
    plt.show()

# -------------------------------
# 4. Customized Seaborn Histogram
# -------------------------------
if len(numeric_df.columns) > 0:
    plt.figure(figsize=(8, 5))

    sns.set_style("darkgrid")

    sns.histplot(
        numeric_df[col],
        bins=10,
        kde=True,
        color="green"
    )

    plt.title(f"Customized Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()
# Out:
# Numeric Columns:
# Index(['Index', 'Price', 'Stock', 'EAN', 'Internal ID'], dtype='str')
#
# Correlation Matrix:
#                 Index     Price     Stock       EAN  Internal ID
# Index        1.000000 -0.078399 -0.114568 -0.087404    -0.223425
# Price       -0.078399  1.000000 -0.022769  0.109010     0.193710
# Stock       -0.114568 -0.022769  1.000000  0.022572    -0.015898
# EAN         -0.087404  0.109010  0.022572  1.000000    -0.158272
# Internal ID -0.223425  0.193710 -0.015898 -0.158272     1.000000
